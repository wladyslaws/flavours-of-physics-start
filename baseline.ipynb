# %% [markdown]
# # Import

# %%
import pandas
from sklearn.ensemble import GradientBoostingClassifier
import evaluation

# %%
from pandas import DataFrame as df

# %% [markdown]
# # Read training data

# %%
from IPython.display import display
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
pandas.options.display.max_columns = None

# %%
import numpy as np

# %%
folder = 'tau_data/'
train = pandas.read_csv(folder + 'training.csv', index_col='id')

# %%
train.head(20)
# Out:
#           LifeTime      dira  FlightDistance  FlightDistanceError        IP  \
# id
# 18453471  0.001578  0.999999       14.033335             0.681401  0.016039
# 5364094   0.000988  0.999705        5.536157             0.302341  0.142163
# 11130990  0.000877  0.999984        6.117302             0.276463  0.034746
# 15173787  0.000854  0.999903        5.228067             0.220739  0.076389
# 1102544   0.001129  0.999995       39.069534             1.898197  0.120936
# 18316844  0.000819  0.995340        3.638690             0.250140  0.232313
# 16522942  0.005190  0.999985       38.920113             0.151273  0.216020
# 3341177   0.000632  0.999601        4.127854             0.149296  0.115681
# 13870233  0.001652  0.999876       11.274630             0.320217  0.177103
# 17913585  0.001048  0.999771        8.732768             0.754453  0.268545
# 11256048  0.000601  0.999767        3.693194             0.201345  0.083370
# ...

# %% [markdown]
# # Define training features
# Here we use subset of the all features to pass the agreement checking

# %%
variables = ['LifeTime',
             'FlightDistance',
             'FlightDistanceError',
             'IP',
             'VertexChi2',
             'pt'
             ]
variables_numbers = [train.columns.get_loc(column) for column in variables if column in train.columns]

# %%
variables_numbers
# Out:
# [0, 2, 3, 4, 6, 7]

# %%
train_cutted = train.drop('signal', axis=1)

# %%
train_cutted.columns
# Out:
# Index([u'LifeTime', u'dira', u'FlightDistance', u'FlightDistanceError', u'IP',
#        u'IPSig', u'VertexChi2', u'pt', u'DOCAone', u'DOCAtwo', u'DOCAthree',
#        u'IP_p0p2', u'IP_p1p2', u'isolationa', u'isolationb', u'isolationc',
#        u'isolationd', u'isolatione', u'isolationf', u'iso', u'CDF1', u'CDF2',
#        u'CDF3', u'ISO_SumBDT', u'p0_IsoBDT', u'p1_IsoBDT', u'p2_IsoBDT',
#        u'p0_track_Chi2Dof', u'p1_track_Chi2Dof', u'p2_track_Chi2Dof', u'p0_IP',
#        u'p1_IP', u'p2_IP', u'p0_IPSig', u'p1_IPSig', u'p2_IPSig', u'p0_pt',
#        u'p1_pt', u'p2_pt', u'p0_p', u'p1_p', u'p2_p', u'p0_eta', u'p1_eta',
#        u'p2_eta', u'SPDhits', u'production', u'mass', u'min_ANNmuon'],
#       dtype='object')

# %%
test = df(train.loc[:,'signal'])
test.head(3)
test.columns
# Out:
# Index([u'signal'], dtype='object')

# %%
test.columns
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-128-12cc77a71e45> in <module>()
# ----> 1 test.columns
#
# /Users/wladyslawsurala/repos/flavours-of-physics-start/flavourstaon/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    4370         if (name in self._internal_names_set or name in self._metadata or
#    4371                 name in self._accessors):
# -> 4372             return object.__getattribute__(self, name)
#    4373         else:
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# AttributeError: 'Series' object has no attribute 'columns'

# %%
dupa = test
test.shape
# Out:
# (67553, 1)

# %%
sc = StandardScaler()

# %%
x_train, x_test, y_train, y_test = train_test_split(train_cutted, test, test_size=0.05, random_state=67)

# %%
cipa = dupa.loc[dupa['signal'] == 1]

# %%
type(x_train)
# Out:
# pandas.core.frame.DataFrame

# %%
train_sets = [x_train, x_test]
for train_set in train_sets:
    sc.fit(train_set)
    train_set_name = [k for k,v in locals().items() if v is train_set][0]
    locals()[train_set_name + '_std'] = df(sc.transform(train_set))
# Out:
# /Users/wladyslawsurala/repos/flavours-of-physics-start/flavourstaon/lib/python2.7/site-packages/ipykernel_launcher.py:5: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   """

# %%
sc.fit(x_train)
x_train_std = df(sc.transform(x_train))
# Out:
# /Users/wladyslawsurala/repos/flavours-of-physics-start/flavourstaon/lib/python2.7/site-packages/ipykernel_launcher.py:2: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.

# %%
part_of_x = df(x_train.loc[variables])
# Out:
# KeyErrorTraceback (most recent call last)
# <ipython-input-277-78cee4542684> in <module>()
# ----> 1 part_of_x = df(x_train.loc[variables])
#
# /Users/wladyslawsurala/repos/flavours-of-physics-start/flavourstaon/lib/python2.7/site-packages/pandas/core/indexing.pyc in __getitem__(self, key)
#    1476
#    1477             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1478             return self._getitem_axis(maybe_callable, axis=axis)
#    1479
#    1480     def _is_scalar_access(self, key):
#
# /Users/wladyslawsurala/repos/flavours-of-physics-start/flavourstaon/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_axis(self, key, axis)
#    1899                     raise ValueError('Cannot index with multidimensional key')
#    1900
# -> 1901                 return self._getitem_iterable(key, axis=axis)
#    1902
#    1903             # nested tuple slicing
#
# ...

# %%
y_train = train['signal']

# %%
y_train.shape
# Out:
# (67553,)

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
x_train.head(3)
# Out:
#           LifeTime      dira  FlightDistance  FlightDistanceError        IP  \
# id
# 2471056   0.001026  0.999999        8.696980             0.481224  0.014682
# 17863639  0.001481  0.999805        9.840313             0.243514  0.168522
# 9342408   0.000706  0.999992        5.338798             0.430183  0.021600
#
#               IPSig  VertexChi2           pt   DOCAone   DOCAtwo  DOCAthree  \
# id
# 2471056    1.049739    4.358210  2844.672119  0.038867  0.018306   0.089933
# 17863639  11.187300    8.091287  3848.789795  0.040801  0.001065   0.034736
# 9342408    1.294134    4.071279  2739.314453  0.019432  0.082876   0.058695
#
#            IP_p0p2   IP_p1p2  isolationa  isolationb  isolationc  isolationd  \
# id
# 2471056   0.166436  0.079956           1           5           7         0.0
# 17863639  0.143090  0.161646           3           1           6         1.0
# 9342408   0.248096  0.082621           2           2          10         0.0
#
# ...

# %%
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-109-e069bd72f889> in <module>()
# ----> 1 dupa.columns
#
# /Users/wladyslawsurala/repos/flavours-of-physics-start/flavourstaon/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    4370         if (name in self._internal_names_set or name in self._metadata or
#    4371                 name in self._accessors):
# -> 4372             return object.__getattribute__(self, name)
#    4373         else:
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# AttributeError: 'Series' object has no attribute 'columns'

# %% [markdown]
# # Baseline training

# %%
baseline = GradientBoostingClassifier(n_estimators=80, learning_rate=0.005, subsample=0.7,
                                      min_samples_leaf=20, max_depth=10, random_state=11)
baseline.fit(x_train[variables], y_train)
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.005, loss='deviance', max_depth=10,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=20, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=80,
#               n_iter_no_change=None, presort='auto', random_state=11,
#               subsample=0.7, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False)

# %%
y_pred = baseline.predict(x_test[variables])

# %%
y_test.shape
# Out:
# (3378, 1)

# %%
y_test_flat = y_test.values.ravel()

# %%
y_test_flat.shape
type(y_test_flat)
# Out:
# numpy.ndarray

# %%
misclassified = np.equal(y_test_flat,y_pred)

# %%
misclassified.sum()
# Out:
# 2608

# %%
misclassified.sum()/float(y_test_flat.shape[0])
# Out:
# 0.7720544701006513

# %%
type(check_agreement.columns)
# Out:
# pandas.core.indexes.range.RangeIndex

# %%
signal
# Out:
# RangeIndex(start=0, stop=48, step=1)

# %% [markdown]
# # Check agreement test

# %%
check_agreement = pandas.read_csv(folder + 'check_agreement.csv', index_col='id')

# %%
signal = check_agreement.columns.get_loc('signal')

# %%
weight = check_agreement.columns.get_loc('weight')

# %%
weight
# Out:
# 47

# %%
check_agreement = pandas.read_csv(folder + 'check_agreement.csv', index_col='id')
agreement_probs = baseline.predict_proba(check_agreement[variables])[:, 1]

ks = evaluation.compute_ks(
    agreement_probs[check_agreement['signal'].values == 0],
    agreement_probs[check_agreement['signal'].values == 1],
    check_agreement[check_agreement['signal'] == 0]['weight'].values,
    check_agreement[check_agreement['signal'] == 1]['weight'].values)
print 'KS metric', ks, ks < 0.09
# Out:
# KS metric 0.05778261483129932 True

# %% [markdown]
# # Check correlation test

# %%
check_correlation = pandas.read_csv(folder + 'check_correlation.csv', index_col='id')
correlation_probs = baseline.predict_proba(check_correlation[variables])[:, 1]
cvm = evaluation.compute_cvm(correlation_probs, check_correlation['mass'])
print 'CvM metric', cvm, cvm < 0.002
# Out:
# CvM metric 0.001011577655539895 True

# %% [markdown]
# # Compute weighted AUC on the training data with min_ANNmuon > 0.4

# %%
train_eval = train[train['min_ANNmuon'] > 0.4]
train_probs = baseline.predict_proba(train_eval[variables])[:, 1]
AUC = evaluation.roc_auc_truncated(train_eval['signal'], train_probs)
print 'AUC', AUC
# Out:
# AUC 0.9760699263888187
# /Users/wladyslawsurala/repos/flavours-of-physics-start/flavourstaon/lib/python2.7/site-packages/sklearn/metrics/ranking.py:104: DeprecationWarning: The 'reorder' parameter has been deprecated in version 0.20 and will be removed in 0.22. It is recommended not to set 'reorder' and ensure that x is monotonic increasing or monotonic decreasing.
#   DeprecationWarning)
# /Users/wladyslawsurala/repos/flavours-of-physics-start/flavourstaon/lib/python2.7/site-packages/sklearn/metrics/ranking.py:104: DeprecationWarning: The 'reorder' parameter has been deprecated in version 0.20 and will be removed in 0.22. It is recommended not to set 'reorder' and ensure that x is monotonic increasing or monotonic decreasing.
#   DeprecationWarning)
# ...

# %% [markdown]
# # Predict test, create file for kaggle

# %%
test = pandas.read_csv(folder + 'test.csv', index_col='id')
result = pandas.DataFrame({'id': test.index})
result['prediction'] = baseline.predict_proba(test[variables])[:, 1]

# %%
result.to_csv('baseline.csv', index=False, sep=',')

# %%
# !ls -l baseline.csv
# Out:
# -rw-r--r--  1 wladyslawsurala  staff  23422382 Sep 29 13:29 baseline.csv

# %%
result.to_csv?
